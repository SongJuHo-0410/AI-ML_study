# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#read csv, csv파일 읽기
data = pd.read_csv(r"C:\Users\sojh0\Desktop\글로벌소프트웨어학과\2022년2학기\01. 인공지능공학\DogMoveData_csv_format\DogMoveData.csv",encoding="cp949",header=0)

# %%
data
# Out:
#           DogID  TestNum    t_sec   ABack_x   ABack_y   ABack_z   ANeck_x  \
# 0            16        1     0.00  0.041504  0.938965 -0.015137 -0.067871
# 1            16        1     0.01  0.041992  0.941895 -0.020020 -0.128906
# 2            16        1     0.02  0.040527  0.939453 -0.004395 -0.158691
# 3            16        1     0.03  0.021484  0.946289  0.007813 -0.122070
# 4            16        1     0.04 -0.000977  0.951172  0.033691 -0.053711
# ...         ...      ...      ...       ...       ...       ...       ...
# 10611063     74        2  1928.19  0.018066  0.436523  0.808105 -0.620605
# 10611064     74        2  1928.20 -0.021973  0.515625  0.813965 -0.671875
# 10611065     74        2  1928.21 -0.041504  0.507324  0.782227 -0.674805
# 10611066     74        2  1928.22 -0.032715  0.484375  0.824219 -0.685059
# 10611067     74        2  1928.23  0.033691  0.432617  0.785645 -0.664063
#
#            ANeck_y   ANeck_z    GBack_x    GBack_y    GBack_z     GNeck_x  \
# ...

# %%
X = data[['ABack_x','ABack_y','ABack_z','ANeck_x', 'ANeck_y', 'ANeck_z', 'GBack_x', 'GBack_y', 'GBack_z', 'GNeck_x', 'GNeck_y', 'GNeck_z']].to_numpy()
Y = data[['Behavior_1']].values.ravel()

# %%
print(X.shape)
print(Y.shape)
# Out:
# (10611068, 12)
# (10611068,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# 훈련 집합과 테스트 집합으로 분할
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.7, random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# 훈련 집합과 테스트 집합으로 분할
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, stratify=Y,random_state=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
clf = KNeighborsClassifier(n_neighbors=15)
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test) 
print(classification_report(y_test, y_pred))
# Out:
# C:\Users\sojh0\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\sojh0\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                        precision    recall  f1-score   support
#
#           <undefined>       0.51      0.75      0.60   1211363
#                Bowing       0.00      0.00      0.00       147
#       Carrying object       0.38      0.00      0.00      5325
#              Drinking       0.37      0.11      0.17     19337
# ...

# %%
rfc = RandomForestClassifier(n_jobs=-1)

model = rfc.fit(x_train,y_train)

y_pred = rfc.predict(x_test)

from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 rfc = RandomForestClassifier(n_jobs=-1)
# ----> 3 model = rfc.fit(x_train,y_train)
#       5 y_pred = rfc.predict(x_test)
#       7 from sklearn.metrics import classification_report
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:474, in BaseForest.fit(self, X, y, sample_weight)
#     463 trees = [
#     464     self._make_estimator(append=False, random_state=random_state)
#     465     for i in range(n_more_estimators)
#     466 ]
#     468 # Parallel loop: we prefer the threading backend as the Cython code
#     469 # for fitting the trees is internally releasing the Python GIL
#     470 # making threading more efficient than multiprocessing in
#     471 # that case. However, for joblib 0.12+ we respect any
# ...

# %%
rfc = RandomForestClassifier(n_estimators=40, n_jobs=-1)

model = rfc.fit(x_train,y_train)

y_pred = rfc.predict(x_test)

from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))

# %%
print(rfc.score(x_train,y_train))
print(rfc.score(x_test,y_test))
# Out:
# 0.9918292855155136
# 0.7680598343679447
